# %% [markdown]
# ## **Synthetic user input & intent Dataset Generator** using **Gemini Flash**.
# ### produces **10 synthetic rows per request**, Covers ** e-commerce intents** (policy, order, product search, general, off-topic, etc.),Generates **messy, lazy, typo-filled, donkey-style user inputs**

# %%
# !pip install google-genai

import os
import json
import re
from google import genai
from google.genai import types
# Out:
# Requirement already satisfied: google-genai in /usr/local/lib/python3.12/dist-packages (1.51.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (4.11.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from google-genai) (2.43.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (2.11.10)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from google-genai) (9.1.2)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.11)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai) (1.3.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (4.9.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-genai) (0.6.1)

# %%
BASE_PROMPT = """
Generate 10 synthetic e-commerce user messages.

Return STRICTLY a JSON array like this:
[
  {"text": "...", "intent": "..."},
  ...
]

NO commentary. NO explanation. NO markdown. ONLY JSON.

INTENT CATEGORIES:
- pricing
- product_availability
- order_status
- refund_policy
- return_policy
- policy_info
- faq
- product_search
- product_sourcing
- trend_analysis
- greeting
- off_topic
- other

User text rules:
- Include typos, slang, lazy short inputs
- Angry customers
- Donkey-level nonsense
- Polite users
- Broken grammar
- Some very short, some longer
"""

# %%
def extract_json(text):
    """
    Extracts the FIRST JSON array found in the text safely.
    Works even if Gemini adds text before or after the JSON.
    """
    pattern = r'\[\s*{.*?}\s*\]'
    match = re.search(pattern, text, flags=re.DOTALL)
    if not match:
        return None
    json_str = match.group(0)
    try:
        return json.loads(json_str)
    except Exception:
        return None

# %%
def generate_synthetic_rows():
    client = genai.Client(api_key="your_gemini_api_key")
    model = "gemini-flash-latest"

    contents = [
        types.Content(
            role="user",
            parts=[types.Part.from_text(text=BASE_PROMPT)],
        )
    ]

    generate_content_config = types.GenerateContentConfig(
        tools=[types.Tool(googleSearch=types.GoogleSearch())],
        thinkingConfig={"thinkingBudget": -1}
    )

    full_output = ""

    for chunk in client.models.generate_content_stream(
        model=model,
        contents=contents,
        config=generate_content_config,
    ):
        if chunk.text:
            full_output += chunk.text

    data = extract_json(full_output)

    if data is None:
        print("[WARNING] Gemini returned INVALID JSON.\nRAW OUTPUT:\n")
        print(full_output)
        return None

    return data

# %%
# Run in Colab
rows = generate_synthetic_rows()
if rows:
    print(json.dumps(rows, indent=2, ensure_ascii=False))
else:
    print("Failed to extract JSON.")
# Out:
# [
#   {
#     "text": "Wheres my stuff it said it wood be here yesterday im pissed",
#     "intent": "order_status"
#   },
#   {
#     "text": "Hello, could you please tell me when the blue size 9 sneakers will be back in stock? Thank you.",
#     "intent": "product_availability"
#   },
#   {
#     "text": "red shirt 2xl",
#     "intent": "product_search"
#   },
#   {
#     "text": "Is this laptop price is best deal or should I wait for sale next month?",
#     "intent": "pricing"
#   },
#   {
#     "text": "yo can i retun this jacket its to big and i lost the recept lmao",
#     "intent": "return_policy"
#   },
#   {
#     "text": "My cat keeps trying to eat the TV remote. Do you sell anti-cat repellent for electronics?",
#     "intent": "off_topic"
#   },
#   {
#     "text": "what is your privacy statement",
#     "intent": "policy_info"
#   },
#   {
#     "text": "I bought a blender but the warranty card wasn't in the box. How do I register it, and what does the standard warranty cover for this specific model?",
#     "intent": "faq"
#   },
#   {
#     "text": "heya",
#     "intent": "greeting"
#   },
#   {
#     "text": "I want my money back NOW! This product is junk! How do I get refund, your policy is confusing!!",
#     "intent": "refund_policy"
#   }
# ]

# %%
import time
import pandas as pd
from google.genai.errors import ServerError # Import ServerError

all_synthetic_data = []

for i in range(100):
    print(f"Generating synthetic rows (Iteration {i + 1}/100)...")

    retries = 0
    max_retries = 5 # Set a maximum number of retries
    while retries < max_retries:
        try:
            new_rows = generate_synthetic_rows()
            if new_rows:
                all_synthetic_data.extend(new_rows)
                print(f"Iteration {i + 1} completed. Total rows collected: {len(all_synthetic_data)}.")
                break # Exit retry loop on success
            else:
                print(f"Iteration {i + 1} failed to generate valid data (JSON extraction issue).")
                break # Exit retry loop if data is invalid but no server error
        except ServerError as e:
            retries += 1
            print(f"[ERROR] ServerError encountered in Iteration {i + 1}: {e}")
            print(f"Retrying in 20 seconds... (Attempt {retries}/{max_retries})")
            time.sleep(20)
        except Exception as e:
            print(f"[ERROR] An unexpected error occurred in Iteration {i + 1}: {e}")
            break # Exit retry loop for other unexpected errors

    if retries == max_retries:
        print(f"[WARNING] Max retries reached for Iteration {i + 1}. Skipping this iteration.")

    # Always pause after an iteration, regardless of success or failure, to respect rate limits
    print("Pausing for 20 seconds to adhere to rate limits...")
    time.sleep(20)

print(f"\nFinished generating all synthetic data. Total unique entries: {len(all_synthetic_data)}")
print("First 5 entries of collected data:")
print(json.dumps(all_synthetic_data[:5], indent=2, ensure_ascii=False))

# Convert to DataFrame and save to CSV
df_synthetic = pd.DataFrame(all_synthetic_data)
df_synthetic.to_csv("synthetic_ecommerce_data.csv", index=False)
print("\nData saved to synthetic_ecommerce_data.csv")
# Out:
# Generating synthetic rows (Iteration 1/100)...
# Iteration 1 completed. Total rows collected: 10.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 2/100)...
# Iteration 2 completed. Total rows collected: 20.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 3/100)...
# Iteration 3 completed. Total rows collected: 30.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 4/100)...
# Iteration 4 completed. Total rows collected: 40.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 5/100)...
# Iteration 5 completed. Total rows collected: 50.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 6/100)...
# Iteration 6 completed. Total rows collected: 60.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 7/100)...
# Iteration 7 completed. Total rows collected: 70.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 8/100)...
# Iteration 8 completed. Total rows collected: 80.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 9/100)...
# Iteration 9 completed. Total rows collected: 90.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 10/100)...
# Iteration 10 completed. Total rows collected: 100.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 11/100)...
# Iteration 11 completed. Total rows collected: 110.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 12/100)...
# Iteration 12 completed. Total rows collected: 120.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 13/100)...
# Iteration 13 completed. Total rows collected: 130.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 14/100)...
# [ERROR] ServerError encountered in Iteration 14: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# Retrying in 20 seconds... (Attempt 1/5)
# Iteration 14 completed. Total rows collected: 140.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 15/100)...
# Iteration 15 completed. Total rows collected: 150.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 16/100)...
# Iteration 16 completed. Total rows collected: 160.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 17/100)...
# Iteration 17 completed. Total rows collected: 170.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 18/100)...
# Iteration 18 completed. Total rows collected: 180.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration

# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 66/100)...
# Iteration 66 completed. Total rows collected: 665.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 67/100)...
# Iteration 67 completed. Total rows collected: 675.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 68/100)...
# Iteration 68 completed. Total rows collected: 685.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 69/100)...
# Iteration 69 completed. Total rows collected: 695.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 70/100)...
# Iteration 70 completed. Total rows collected: 705.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 71/100)...
# Iteration 71 completed. Total rows collected: 715.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 72/100)...
# Iteration 72 completed. Total rows collected: 725.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 73/100)...
# Iteration 73 completed. Total rows collected: 735.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 74/100)...
# Iteration 74 completed. Total rows collected: 745.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 75/100)...
# Iteration 75 completed. Total rows collected: 755.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 76/100)...
# Iteration 76 completed. Total rows collected: 765.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 77/100)...
# Iteration 77 completed. Total rows collected: 775.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 78/100)...
# Iteration 78 completed. Total rows collected: 785.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 79/100)...
# Iteration 79 completed. Total rows collected: 795.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 80/100)...
# Iteration 80 completed. Total rows collected: 805.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 81/100)...
# Iteration 81 completed. Total rows collected: 815.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 82/100)...
# Iteration 82 completed. Total rows collected: 825.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 83/100)...
# Iteration 83 completed. Total rows collected: 835.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 84/100)...
# Iteration 84 completed. Total rows collected: 845.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 85/100)...
# Iteration 85 completed. Total rows collected: 855.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 86/100)...
# Iteration 86 completed. Total rows collected: 865.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 87/100)...
# Iteration 87 completed. Total rows collected: 875.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 88/100)...
# Iteration 88 completed. Total rows collected: 885.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 89/100)...
# Iteration 89 completed. Total rows collected: 895.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 90/100)...
# Iteration 90 completed. Total rows collected: 905.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 91/100)...
# Iteration 91 completed. Total rows collected: 915.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 92/100)...
# Iteration 92 completed. Total rows collected: 925.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 93/100)...
# Iteration 93 completed. Total rows collected: 935.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 94/100)...
# Iteration 94 completed. Total rows collected: 945.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 95/100)...
# Iteration 95 completed. Total rows collected: 955.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 96/100)...
# Iteration 96 completed. Total rows collected: 965.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 97/100)...
# Iteration 97 completed. Total rows collected: 975.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 98/100)...
# Iteration 98 completed. Total rows collected: 985.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 99/100)...
# Iteration 99 completed. Total rows collected: 995.
# Pausing for 20 seconds to adhere to rate limits...
# Generating synthetic rows (Iteration 100/100)...
# Iteration 100 completed. Total rows collected: 1005.
# Pausing for 20 seconds to adhere to rate limits...
#
# Finished generating all synthetic data. Total unique entries: 1005
# First 5 entries of collected data:
# [
#   {
#     "text": "Hey, is the blue jacket back in stock yet? SKU J004.",
#     "intent": "product_availability"
#   },
#   {
#     "text": "Where the heck is my package?? Order # 998734 I paid extra for fast shipping this is UNACCEPTABLE.",
#     "intent": "order_status"
#   },
#   {
#     "text": "What is ur refund policy for electronics if i opn the box? Is it 30 days?",
#     "intent": "refund_policy"
#   },
#   {
#     "text": "Can you tell me what the biggest selling type of sneaker was last quarter, preferably running shoes data?",
#     "intent": "trend_analysis"
#   },
#   {
#     "text": "Yo. I saw the price drop like 5 bux on that TV last week. Can i get a price match or somethin?",
#     "intent": "pricing"
#   }
# ]
#
# Data saved to synthetic_ecommerce_data.csv
